# %%
import numpy as np
import pandas as pd
import datetime as dt
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("experiment.csv")
df = pd.DataFrame(data)

# %%
exp = df[:100]
if exp.iloc[2]["invoice_currency"]== "USD":
    print(True)
# Out:
# True

# %%
exp
# Out:
#    business_code cust_number       name_customer           clear_date  \
# 0           U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1           U001  0200980828              BEN E   2019-08-08 00:00:00
# 2           U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3           CA02  0140105686            SYSC llc                  NaN
# 4           U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# ..           ...         ...                 ...                  ...
# 95          U001  0200769623         WAL-MAR llc                  NaN
# 96          U001  0200783609  PROFIC corporation  2020-01-29 00:00:00
# 97          U001  0100033266        INTERN trust  2019-12-24 00:00:00
# 98          U001  0200744019     TARG associates  2020-02-26 00:00:00
# 99          U001  0200705089     JETR foundation  2019-08-07 00:00:00
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 0          2020.0  1.930438e+09   2020-01-26              20200125
# 1          2019.0  1.929646e+09   2019-07-22              20190722
# 2          2019.0  1.929874e+09   2019-09-14              20190914
# 3          2020.0  2.960623e+09   2020-03-30              20200330
# 4          2019.0  1.930148e+09   2019-11-13              20191113
# ..            ...           ...          ...                   ...
# 95         2020.0  1.930753e+09   2020-04-06              20200406
# 96         2020.0  1.930396e+09   2020-01-14              20200114
# 97         2019.0  1.930174e+09   2019-11-25              20191120
# 98         2020.0  1.930512e+09   2020-02-11              20200211
# 99         2019.0  1.929651e+09   2019-07-23              20190723
#
#     document_create_date.1  due_in_date invoice_currency document type  \
# 0                 20200126   20200210.0              USD            RV
# 1                 20190722   20190811.0              USD            RV
# 2                 20190914   20190929.0              USD            RV
# 3                 20200330   20200410.0              CAD            RV
# 4                 20191113   20191128.0              USD            RV
# ..                     ...          ...              ...           ...
# 95                20200406   20200421.0              USD            RV
# 96                20200114   20200129.0              USD            RV
# 97                20191125   20191210.0              USD            RV
# 98                20200211   20200226.0              USD            RV
# 99                20190723   20190807.0              USD            RV
#
#     posting_id  area_business  total_open_amount  baseline_create_date  \
# 0          1.0            NaN           54273.28            20200126.0
# 1          1.0            NaN           79656.60            20190722.0
# 2          1.0            NaN            2253.86            20190914.0
# 3          1.0            NaN            3299.70            20200331.0
# 4          1.0            NaN           33133.29            20191113.0
# ..         ...            ...                ...                   ...
# 95         1.0            NaN           11394.84            20200406.0
# 96         1.0            NaN           20306.46            20200114.0
# 97         1.0            NaN           17243.10            20191125.0
# 98         1.0            NaN           22993.63            20200211.0
# 99         1.0            NaN           18939.75            20190723.0
#
#    cust_payment_terms    invoice_id  isOpen
# 0                NAH4  1.930438e+09       0
# 1                NAD1  1.929646e+09       0
# 2                NAA8  1.929874e+09       0
# 3                CA10  2.960623e+09       1
# 4                NAH4  1.930148e+09       0
# ..                ...           ...     ...
# 95               NAH4  1.930753e+09       1
# 96               NAA8  1.930396e+09       0
# 97               NAA8  1.930174e+09       0
# 98               NAA8  1.930512e+09       0
# 99               NAA8  1.929651e+09       0
#
# [100 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   buisness_year           50000 non-null  float64
#  5   doc_id                  50000 non-null  float64
#  6   posting_date            50000 non-null  object
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  float64
#  10  invoice_currency        50000 non-null  object
#  11  document type           50000 non-null  object
#  12  posting_id              50000 non-null  float64
#  13  area_business           0 non-null      float64
#  14  total_open_amount       50000 non-null  float64
#  15  baseline_create_date    50000 non-null  float64
#  16  cust_payment_terms      50000 non-null  object
#  17  invoice_id              49994 non-null  float64
#  18  isOpen                  50000 non-null  int64
# dtypes: float64(8), int64(3), object(8)
# memory usage: 7.2+ MB

# %%
a = df["cust_number"]

# %%
def integers_test(x):
    ref = dict(df['cust_number'].value_counts())
    if ref.get(x):
        return ref[x]
    
df['cust_number'] = df['cust_number'].apply(integers_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <module>
#       3     if ref.get(x):
#       4         return ref[x]
# ----> 6 df['cust_number'] = df['cust_number'].apply(integers_test)
#
# File e:\conda\lib\site-packages\pandas\core\series.py:4430, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4320 def apply(
#    4321     self,
#    4322     func: AggFuncType,
#    (...)
#    4325     **kwargs,
#    4326 ) -> DataFrame | Series:
#    4327     """
#    4328     Invoke function on values of Series.
#    4329
#    (...)
#    4428     dtype: float64
#    4429     """
# -> 4430     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File e:\conda\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File e:\conda\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File e:\conda\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [19], in integers_test(x)
#       1 def integers_test(x):
# ----> 2     ref = dict(df['cust_number'].value_counts())
#       3     if ref.get(x):
#       4         return ref[x]
#
# File e:\conda\lib\site-packages\pandas\core\base.py:970, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     884 def value_counts(
#     885     self,
#     886     normalize: bool = False,
#    (...)
#     890     dropna: bool = True,
#     891 ):
#     892     """
#     893     Return a Series containing counts of unique values.
#     894
#    (...)
#     968     dtype: int64
#     969     """
# --> 970     return value_counts(
#     971         self,
#     972         sort=sort,
#     973         ascending=ascending,
#     974         normalize=normalize,
#     975         bins=bins,
#     976         dropna=dropna,
#     977     )
#
# File e:\conda\lib\site-packages\pandas\core\algorithms.py:870, in value_counts(values, sort, ascending, normalize, bins, dropna)
#     867         result = Series(counts, index=keys, name=name)
#     869 if sort:
# --> 870     result = result.sort_values(ascending=ascending)
#     872 if normalize:
#     873     result = result / counts.sum()
#
# File e:\conda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File e:\conda\lib\site-packages\pandas\core\series.py:3529, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3527 # GH 35922. Make sorting stable by leveraging nargsort
#    3528 values_to_sort = ensure_key_mapped(self, key)._values if key else self._values
# -> 3529 sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3531 result = self._constructor(
#    3532     self._values[sorted_index], index=self.index[sorted_index]
#    3533 )
#    3535 if ignore_index:
#
# File e:\conda\lib\site-packages\pandas\core\sorting.py:404, in nargsort(items, kind, ascending, na_position, key, mask)
#     401     items = np.asanyarray(items)
#     403 idx = np.arange(len(items))
# --> 404 non_nans = items[~mask]
#     405 non_nan_idx = idx[~mask]
#     407 nan_idx = np.nonzero(mask)[0]
#
# KeyboardInterrupt:

# %%
df.info()
