# %%
import numpy as np
import pandas as pd
import datetime as dt
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("experiment.csv")
df = pd.DataFrame(data)

# %%
exp = df[:100]
if exp.iloc[2]["invoice_currency"]== "USD":
    print(True)
# Out:
# True

# %%
exp
# Out:
#    business_code cust_number       name_customer           clear_date  \
# 0           U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1           U001  0200980828              BEN E   2019-08-08 00:00:00
# 2           U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3           CA02  0140105686            SYSC llc                  NaN
# 4           U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# ..           ...         ...                 ...                  ...
# 95          U001  0200769623         WAL-MAR llc                  NaN
# 96          U001  0200783609  PROFIC corporation  2020-01-29 00:00:00
# 97          U001  0100033266        INTERN trust  2019-12-24 00:00:00
# 98          U001  0200744019     TARG associates  2020-02-26 00:00:00
# 99          U001  0200705089     JETR foundation  2019-08-07 00:00:00
#
#     buisness_year        doc_id posting_date  document_create_date  \
# ...

# %%
for i in range(1,len(exp)):
    curr_col = exp.iloc[i]
    if (curr_col["invoice_currency"])== "CAD":
        curr_col.replace(['CAD'],'USA')
        curr_col["total_open_amount"]* .75 
        print(curr_col)
# Out:
# business_code                     CA02
# cust_number                 0140105686
# name_customer                 SYSC llc
# clear_date                         NaN
# buisness_year                   2020.0
# doc_id                    2960623488.0
# posting_date                2020-03-30
# document_create_date          20200330
# document_create_date.1        20200330
# due_in_date                 20200410.0
# invoice_currency                   CAD
# document type                       RV
# posting_id                         1.0
# area_business                      NaN
# total_open_amount               3299.7
# baseline_create_date        20200331.0
# cust_payment_terms                CA10
# invoice_id                2960623488.0
# isOpen                               1
# Name: 3, dtype: object
# business_code                            CA02
# cust_number                        0140106181
# name_customer                THE  corporation
# clear_date                2019-12-04 00:00:00
# ...

# %%
i=5
exp.iloc[i]
# Out:
# business_code                            CA02
# cust_number                        0140106181
# name_customer                THE  corporation
# clear_date                2019-12-04 00:00:00
# buisness_year                          2019.0
# doc_id                           2960581231.0
# posting_date                       2019-09-20
# document_create_date                 20190920
# document_create_date.1               20190920
# due_in_date                        20191004.0
# invoice_currency                          CAD
# document type                              RV
# posting_id                                1.0
# area_business                             NaN
# total_open_amount                    22225.84
# baseline_create_date               20190924.0
# cust_payment_terms                       CA10
# invoice_id                       2960581231.0
# isOpen                                      0
# Name: 5, dtype: object

# %%
exp["invoice_currency"] == "CAD"
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: invoice_currency, Length: 100, dtype: bool

# %%
exp.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1          U001  0200980828              BEN E   2019-08-08 00:00:00
# 2          U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3          CA02  0140105686            SYSC llc                  NaN
# 4          U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  1.930438e+09   2020-01-26              20200125
# 1         2019.0  1.929646e+09   2019-07-22              20190722
# 2         2019.0  1.929874e+09   2019-09-14              20190914
# 3         2020.0  2.960623e+09   2020-03-30              20200330
# 4         2019.0  1.930148e+09   2019-11-13              20191113
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200126   20200210.0              USD            RV
# ...

# %%
count = 1
for i in range(len(exp)-1):
    a = exp.iloc[[i]]
    c= str(a["invoice_currency"])
   
    if((c) =="CAD"):
        count =count+1 
    #print(invoice, amount)
count
# Out:
# 1

# %%
len(exp)
# Out:
# 1

# %%
s = pd.Series([1, 2, 3, 4, 5])

s.replace(1, 5)
# Out:
# 0    5
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
exp["invoice_currency"] = exp["invoice_currency"].str.replace("CAD", "USD")
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_7176\3814501981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp["invoice_currency"] = exp["invoice_currency"].str.replace("CAD", "USD")

# %%
exp
# Out:
#    business_code cust_number       name_customer           clear_date  \
# 0           U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1           U001  0200980828              BEN E   2019-08-08 00:00:00
# 2           U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3           CA02  0140105686            SYSC llc                  NaN
# 4           U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# ..           ...         ...                 ...                  ...
# 95          U001  0200769623         WAL-MAR llc                  NaN
# 96          U001  0200783609  PROFIC corporation  2020-01-29 00:00:00
# 97          U001  0100033266        INTERN trust  2019-12-24 00:00:00
# 98          U001  0200744019     TARG associates  2020-02-26 00:00:00
# 99          U001  0200705089     JETR foundation  2019-08-07 00:00:00
#
#     buisness_year        doc_id posting_date  document_create_date  \
# ...
